# %%
import requests
from bs4 import BeautifulSoup

import webbrowser, sys

name_to_search = input("Which celeb you want to look up?: ")

entire_url_to_query_to_get_actor_code = 'http://www.imdb.com/find?ref_=nv_sr_fn&q=' + name_to_search


r = requests.get(entire_url_to_query_to_get_actor_code, verify=False,)

soup = BeautifulSoup(r.content , "lxml", )


actor = soup.find('td' , class_='result_text')


encoded_name_link = actor.find('a')
uri_portion = ((encoded_name_link['href']))
print(uri_portion)

entire_url_to_query_to_get_actor_page = 'http://www.imdb.com' + uri_portion
actor_page_response = requests.get(entire_url_to_query_to_get_actor_page, verify=False,  )
actor_soup = BeautifulSoup(actor_page_response.content , 'lxml')
print (actor_soup.prettify())
# Out:
# Which celeb you want to look up?: al_pacino
# C:\Users\rohanu\AppData\Local\Continuum\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /name/nm0000199/?ref_=fn_al_nm_1
# C:\Users\rohanu\AppData\Local\Continuum\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="app-id=342792525, app-argument=imdb:///name/nm0000199?src=mdot" name="apple-itunes-app"/>
#   <script type="text/javascript">
#    var IMDbTimer={starttime: new Date().getTime(),pt:'java'};
#   </script>
#   <script>
#    if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
#   </script>
#   <script>
#    (function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);
#   </script>
#   <title>
#    Al Pacino - IMDb
#   </title>
#   <script>
#    (function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);
#   </script>
#   <script>
#    if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
#   </script>
#   <script>
#    if (typeof uex == 'function') {
#       uex("ld", "LoadTitle", {wb: 1});
#     }
#   </script>
#   <link href="https://www.imdb.com/name/nm0000199/" rel="canonical"/>
#   <meta content="http://www.imdb.com/name/nm0000199/" property="og:url"/>
#   <link href="https://m.imdb.com/name/nm0000199/" media="only screen and (max-width: 640px)" rel="alternate"/>
#   <script>
#    if (typeof uet == 'function') {
#       uet("bb", "LoadIcons", {wb: 1});
#     }
#   </script>
#   <script>
#    (function(t){ (t.events = t.events || {})["csm_head_pre_icon"] = new Date().getTime(); })(IMDbTimer);
#   </script>
#   <link href="https://m.media-amazon.com/images/G/01/imdb/images/safari-favicon-517611381._CB483525257_.svg" mask="" rel="icon" sizes="any"/>
#   <link href="https://m.media-amazon.com/images/G/01/imdb/images/favicon-2165806970._CB470047330_.ico" rel="icon" type="image/ico"/>
#   <meta content="#000000" name="theme-color"/>
#   <link href="https://m.media-amazon.com/images/G/01/imdb/images/desktop-favicon-2165806970._CB484110913_.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="https://m.media-amazon.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-4151659188._CB483525313_.png" rel="apple-touch-icon"/>
#   <link href="https://m.media-amazon.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-76x76-53536248._CB484146059_.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="https://m.media-amazon.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-120x120-2442878471._CB483525250_.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="https://m.media-amazon.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-152x152-1475823641._CB470042035_.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="https://m.media-amazon.com/images/G/01/imdb/images/imdbsearch-3349468880._CB470047351_.xml" rel="search" title="IMDb" type="application/opensearchdescription+xml"/>
#   <script>
#    (function(t){ (t.events = t.events || {})["csm_head_post_icon"] = new Date().getTime(); })(IMDbTimer);
#   </script>
#   <script>
#    if (typeof uet == 'function') {
#       uet("be", "LoadIcons", {wb: 1});
#     }
#   </script>
#   <script>
#    if (typeof uex == 'function') {
#       uex("ld", "LoadIcons", {wb: 1});
#     }
#   </script>
#   <meta content="nm0000199" property="pageId"/>
#   <meta content="name" property="pageType"/>
#   <meta content="main" property="subpageType"/>
#   <link href="https://m.media-amazon.com/images/M/MV5BMTQzMzg1ODAyNl5BMl5BanBnXkFtZTYwMjAxODQ1._V1_UY1200_CR84,0,630,1200_AL_.jpg" rel="image_src"/>
#   <meta content="https://m.media-amazon.com/images/M/MV5BMTQzMzg1ODAyNl5BMl5BanBnXkFtZTYwMjAxODQ1._V1_UY1200_CR84,0,630,1200_AL_.jpg" property="og:image"/>
#   <meta content="actor" property="og:type"/>
#   <meta content="115109575169727" property="fb:app_id"/>
#   <meta content="Al Pacino" property="og:title"/>
#   <meta content="IMDb" property="og:site_name"/>
#   <meta content="Al Pacino - IMDb" name="title"/>
#   <meta content="Al Pacino, Actor: Serpico. One of the greatest actors in all of film history, Al Pacino established himself during one of cinema's most vibrant decades, the 1970s, and has become an enduring and iconic figure in the world of American movies. Alfredo James Pacino was born on April 25, 1940 in Manhattan, New York City, to an Italian-American family. His parents, Rose (Gerardi)..." name="description"/>
#   <meta content="Al Pacino, Actor: Serpico. One of the greatest actors in all of film history, Al Pacino established himself during one of cinema's most vibrant decades, the 1970s, and has become an enduring and iconic figure in the world of American movies. Alfredo James Pacino was born on April 25, 1940 in Manhattan, New York City, to an Italian-American family. His parents, Rose (Gerardi)..." property="og:description"/>
#   <meta content="Biography, Photos, Awards, News" name="keywords"/>
#   <meta content="GN72WZ6FG5YZFYMW8XF3" name="request_id"/>
#   <script type="application/ld+json">
#    {
#   "@context": "http://schema.org",
#   "@type": "Person",
#   "url": "/name/nm0000199/",
#   "name": "Al Pacino",
#   "image": "https://m.media-amazon.com/images/M/MV5BMTQzMzg1ODAyNl5BMl5BanBnXkFtZTYwMjAxODQ1._V1_.jpg",
#   "jobTitle": [
#     "Actor",
#     "Producer",
#     "Soundtrack"
#   ],
#   "description": "One of the greatest actors in all of film history, Al Pacino established himself during one of cinema\u0027s most vibrant decades, the 1970s, and has become an enduring and iconic figure in the world of American movies. Alfredo James Pacino was born on April 25, 1940 in Manhattan, New York City, to an Italian-American family. His parents, Rose (Gerardi)...",
#   "birthDate": "1940-04-25"
# }
#   </script>
#   <script>
#    if (typeof uet == 'function') {
#       uet("bb", "LoadCSS", {wb: 1});
#     }
#   </script>
#   <script>
#    (function(t){ (t.events = t.events || {})["csm_head_pre_css"] = new Date().getTime(); })(IMDbTimer);
#   </script>
#   
#           </a>
#          </p>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <script>
#       if (typeof uet == 'function') {
#       uet("ne");
#     }
#      </script>
#      <!-- no content received for slot: navstrip -->
#      <!-- no content received for slot: injected_navstrip -->
#     </div>
#     <div class="pagecontent" id="pagecontent">
#      <!-- no content received for slot: injected_billboard -->
#      <div class="redesign" id="content-2-wide">
#       <div class="maindetails_center" id="maindetails_center_top">
#        <div class="article name-overview">
#         <script>
#          if (typeof uet == 'function') {
#       uet("bb", "NameOverviewWidget", {wb: 1});
#     }
#         </script>
#         <script>
#          if ('csm' in window) {
#         csm.measure('csm_NameOverviewWidget_started');
#       }
#         </script>
#         <div id="name-overview-widget">
#          <table border="0" cellpadding="0" cellspacing="0" id="name-overview-widget-layout">
#           <tbody>
#            <tr>
#             <td id="img_primary" rowspan="2">
#              <div class="image">
#               <a href="/name/nm0000199/mediaviewer/rm3894385408?ref_=nm_ov_ph">
#                <img alt="Al Pacino Picture" height="317" id="name-poster" src="https://m.media-amazon.com/images/M/MV5BMTQzMzg1ODAyNl5BMl5BanBnXkFtZTYwMjAxODQ1._V1_UX214_CR0,0,214,317_AL_.jpg" title="Al Pacino Picture" width="214"/>
#               </a>
#              </div>
#             </td>
#             <td id="overview-top">
#              <div id="prometer_container">
#               <div class="meter-collapsed down three-line" id="prometer">
#                <div id="meterHeaderBox">
#                 <div class="meterToggleOnHover">
#                  STARmeter
#                 </div>
#                 <a href="https://pro.imdb.com/name/nm0000199?rf=cons_nm_meter&amp;ref_=cons_nm_meter" id="meterRank">
#                  Top 500
#                 </a>
#                </div>
#                <div class="meterToggleOnHover" id="meterChangeRow">
#                 <span>
#                  Down
#                 </span>
#                 <span id="meterChange">
#                  43
#                 </span>
#                 <span>
#                  this week
#                 </span>
#                </div>
#                <div class="meterToggleOnHover" id="meterSeeMoreRow">
#                 <a href="https://pro.imdb.com/name/nm0000199?rf=cons_nm_meter&amp;ref_=cons_nm_meter">
#                  View rank on IMDbPro
#                 </a>
#                 <span>
#                  »
#                 </span>
#                </div>
#               </div>
#              </div>
#              <h1 class="header">
#               <span class="itemprop">
#                Al Pacino
#               </span>
#               <span>
#                (I)
#               </span>
#              </h1>
#              <div class="infobar" id="name-job-categories">
#               <a href="#actor" onclick="nameJobCategoriesClickHandler(this)">
#                <span class="itemprop">
#                 Actor
#                </span>
#               </a>
#               <span class="ghost">
#                |
#               </span>
#               <a href="#producer" onclick="nameJobCategoriesClickHandler(this)">
#                <span class="itemprop">
#                 Producer
#                </span>
#               </a>
#               <span class="ghost">
#                |
#               </span>
#               <a href="#soundtrack" onclick="nameJobCategoriesClickHandler(this)">
#                <span class="itemprop">
#                 Soundtrack
#                </span>
#               </a>
#              </div>
#              <hr/>
#              <div id="resume-teaser">
#               <div id="add-photos-pro">
#               </div>
#               <div id="resume-links">
#               </div>
#              </div>
#              <div class="txt-block" id="name-bio-text">
#               <div class="name-trivia-bio-text">
#                <div class="inline">
#                 One of the greatest actors in all of film history, Al Pacino established himself during one of cinema's most vibrant decades, the 1970s, and has become an enduring and iconic figure in the world of American movies. Alfredo James Pacino was born on April 25, 1940 in Manhattan, New York City, to an Italian-American family. His parents, Rose (Gerardi)...
#                 <span class="see-more inline nobr-only">
#                  <a href="/name/nm0000199/bio?ref_=nm_ov_bio_sm">
#                   See full bio
#                  </a>
#                  »
#                 </span>
#                </div>
#               </div>
#              </div>
#              <div class="txt-block" id="name-born-info">
#               <h4 class="inline">
#                Born:
#               </h4>
#               <time datetime="1940-4-25">
#                <a href="/search/name?birth_monthday=4-25&amp;refine=birth_monthday&amp;ref_=nm_ov_bth_monthday">
#                 April 25
#                </a>
#                ,
#                <a href="/search/name?birth_year=1940&amp;ref_=nm_ov_bth_year">
#                 1940
#                </a>
#               </time>
#               in
#               <a href="/search/name?birth_place=Manhattan,%20New%20York%20City,%20New%20York,%20USA&amp;ref_=nm_ov_bth_place">
#                Manhattan, New York City, New York, USA
#               </a>
#              </div>
#             </td>
#            </tr>
#            <tr>
#             <td id="overview-middle">
#              <div class="pro-list" id="name-pro-info">
#               <div id="name-pro-info-redesign">
#                <span class="pro-list-title">
#                 <a href="https://pro.imdb.com/name/nm0000199?rf=cons_nm_more&amp;ref_=cons_nm_more">
#                  More at IMDbPro
#                 </a>
#                 »
#                </span>
#                <a href="https://pro.imdb.com/name/nm0000199?rf=cons_nm_contact&amp;ref_=cons_nm_contact">
#                 <img alt="Contact Info on IMDbPro" class="absmiddle" height="13" src="https://m.media-amazon.com/images/G/01/imdb/IMDbConsumerSiteNameProViews/images/icons/blue_phone-2836107444._CB470257501_.png" srcset="https://m.media-amazon.com/images/G/01/imdb/IMDbConsumerSiteNameProViews/images/icons/blue_phone-2836107444._CB470257501_.png 1x,
# https://m.media-amazon.com/images/G/01/imdb/IMDbConsumerSiteNameProViews/images/icons/blue_phone_2x-1593119141._CB470256788_.png 2x" width="13"/>
#                </a>
#                <strong>
#                 Contact Info:
#                </strong>
#                <a href="https://pro.imdb.com/name/nm0000199?rf=cons_nm_contact&amp;ref_=cons_nm_contact">
#                 View agent, publicist, legal on IMDbPro
#                </a>
#               </div>
#              </div>
#             </td>
#            </tr>
#           </tbody>
#          </table>
#          <div class="mediastrip_container">
#           <div class="mediastrip">
#            <a href="/name/nm0000199/mediaviewer/rm853440768?context=default&amp;ref_=nm_phs_md_1">
#             <img alt="Al Pacino in Scent of a Woman (1992)" class="loadlate hidden " height="99" loadlate="https://m.media-amazon.com/images/M/MV5BMDAyYTkxMmItMTVlNS00Y2JmLTkwZDktODlmNzUzYWZmNjQ0XkEyXkFqcGdeQXVyNjUwNzk3NDc@._V1_UY99_CR48,0,99,99_AL_.jpg" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/small/unknown-1394846836._CB470041629_.png" title="Al Pacino in Scent of a Woman (1992)" width="99"/>
#            </a>
#            <a href="/name/nm0000199/mediaviewer/rm886995200?context=default&amp;ref_=nm_phs_md_2">
#             <img alt="Al Pacino and Chris O'Donnell in Scent of a Woman (1992)" class="loadlate hidden " height="99" loadlate="https://m.media-amazon.com/images/M/MV5BOTk4M2ZkMzAtYjExMC00Y2ZmLTg5ZGQtOWM2NGM4YzVmODg0XkEyXkFqcGdeQXVyNjUwNzk3NDc@._V1_UY99_CR49,0,99,99_AL_.jpg" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/small/unknown-1394846836._CB470041629_.png" title="Al Pacino and Chris O'Donnell in Scent of a Woman (1992)" width="99"/>
#            </a>
#            <a href="/name/nm0000199/mediaviewer/rm937326848?context=default&amp;ref_=nm_phs_md_3">
#             <img alt="Al Pacino and Gabrielle Anwar in Scent of a Woman (1992)" class="loadlate hidden " height="99" loadlate="https://m.media-amazon.com/images/M/MV5BZmZhMTk5MDgtZjI2MC00NGMyLWI2NjgtZTNjMDIwZjUyNmJiXkEyXkFqcGdeQXVyNjUwNzk3NDc@._V1_UY99_CR49,0,99,99_AL_.jpg" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/small/unknown-1394846836._CB470041629_.png" title="Al Pacino and Gabrielle Anwar in Scent of a Woman (1992)" width="99"/>
#            </a>
#            <a href="/name/nm0000199/mediaviewer/rm719223040?context=default&amp;ref_=nm_phs_md_4">
#             <img alt="Al Pacino in Scent of a Woman (1992)" class="loadlate hidden " height="99" loadlate="https://m.media-amazon.com/images/M/MV5BNTgzMmYxNjgtYTc5OC00OWY2LWE4MzQtYzFmZmZiMjZmM2FlXkEyXkFqcGdeQXVyNjUwNzk3NDc@._V1_UY99_CR49,0,99,99_AL_.jpg" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/small/unknown-1394846836._CB470041629_.png" title="Al Pacino in Scent of a Woman (1992)" width="99"/>
#            </a>
#            <a href="/name/nm0000199/mediaviewer/rm769554688?context=default&amp;ref_=nm_phs_md_5">
#             <img alt="Al Pacino in Scent of a Woman (1992)" class="loadlate hidden " height="99" loadlate="https://m.media-amazon.com/images/M/MV5BOWQ3ZjRlMzUtMzQ0Ny00OTU2LWFhZDktOTI3YjZjOGNlYTUxXkEyXkFqcGdeQXVyNjUwNzk3NDc@._V1_UY99_CR48,0,99,99_AL_.jpg" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/small/unknown-1394846836._CB470041629_.png" title="Al Pacino in Scent of a Woman (1992)" width="99"/>
#            </a>
#            <a href="/name/nm0000199/mediaviewer/rm585005312?context=default&amp;ref_=nm_phs_md_6">
#             <img alt="Al Pacino, Chris O'Donnell, Richard Venture, and Bradley Whitford in Scent of a Woman (1992)" class="loadlate hidden " height="99" loadlate="https://m.media-amazon.com/images/M/MV5BY2Y1MWFhNGEtNTVjYS00MzIxLThlY2EtNTg4ZmRjZDBkNzU2XkEyXkFqcGdeQXVyNjUwNzk3NDc@._V1_UY99_CR48,0,99,99_AL_.jpg" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/small/unknown-1394846836._CB470041629_.png" title="Al Pacino, Chris O'Donnell, Richard Venture, and Bradley Whitford in Scent of a Woman (1992)" width="99"/>
#            </a>
#           </div>
#           <div class="see-more">
#            <a href="/name/nm0000199/mediaindex?ref_=nm_phs_md_sm">
#             <span class="titlePageSprite showAllVidsAndPics">
#             </span>
#            </a>
#            <a href="/name/nm0000199/mediaindex?ref_=nm_phs_md_sm">
#             1529 photos
#            </a>
#            <span class="ghost">
#             |
#            </span>
#            <a href="/name/nm0000199/videogallery?ref_=nm_phs_vi">
#             90 videos
#            </a>
#            »
#           </div>
#          </div>
#         </div>
#         <script>
#          if ('csm' in window) {
#         csm.measure('csm_NameOverviewWidget_finished');
#       }
#         </script>
#         <script>
#          if (typeof uet == 'function') {
#       uet("be", "NameOverviewWidget", {wb: 1});
#     }
#         </script>
#         <script>
#          if (typeof uex == 'function') {
#       uex("ld", "NameOverviewWidget", {wb: 1});
#     }
#         </script>
#        </div>
#        <script>
#         if (typeof uet == 'function') {
#       uet("af");
#     }
#        </script>
#        <script>
#         if ('csm' in window) {
#       csm.measure('csm_atf_main');
#     }
#        </script>
#       </div>
#       <script>
#        if (typeof uet == 'function') {
#       uet("cf");
#     }
#       </script>
#       <div class="maindetails_sidebar" data-caller-name="name-main" id="maindetails_sidebar_bottom">
#        <script>
#         if ('csm' in window) {
#       csm.measure('csm_atf_sidebar');
#     }
#        </script>
#        <!-- no content received for slot: top_rhs -->
#        <div class="aux-content-widget-3 links subnav" div="quicklinks">
#         <h3>
#          Quick Links
#         </h3>
#         <div id="maindetails_quicklinks">
#          <div class="split_0">
#           <ul class="quicklinks">
#            <li class="subnav_item_main">
#             <span class="nobr-only">
#              <a class="link" href="/name/nm0000199/bio?ref_=nm_ql_1">
#               Biography
#              </a>
#             </span>
#            </li>
#            <li class="subnav_item_main">
#             <span class="nobr-only">
#              <a class="link" href="/name/nm0000199/awards?ref_=nm_ql_2">
#               Awards
#              </a>
#             </span>
#            </li>
#            <li class="subnav_item_main">
#             <span class="nobr-only">
#              <a class="link" href="/name/nm0000199/mediaindex?ref_=nm_ql_3">
#               Photo Gallery
#              </a>
#             </span>
#            </li>
#           </ul>
#          </div>
#          <div class="split_1">
#           <ul class="quicklinks">
#            <li class="subnav_item_main">
#             <span class="nobr-only">
#              <a class="link" href="/name/nm0000199/?nmdp=1&amp;ref_=nm_ql_4#filmography">
#               Filmography
#               <span class="ghost quicklink_modifier">
#                (by Job)
#               </span>
#              </a>
#             </span>
#            </li>
#            <li class="subnav_item_main">
#             <span class="nobr-only">
#              <a class="link" href="/name/nm0000199/videogallery?ref_=nm_ql_5">
#               Trailers and Videos
#              </a>
#             </span>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <hr/>
#         <div id="full_subnav">
#          <h4>
#           Filmography
#          </h4>
#          <ul class="quicklinks">
#           <li class="subnav_item_main">
#            <span class="nobr-only">
#             <a class="link" href="/filmosearch?sort=year&amp;explore=title_type&amp;role=nm0000199&amp;ref_=nm_ql_flmg_1">
#              <span class="ghost">
#               by
#              </span>
#              Year
#             </a>
#            </span>
#           </li>
#           <li class="subnav_item_main">
#            <span class="nobr-only">
#             <a class="link" href="/name/nm0000199/?nmdp=1&amp;ref_=nm_ql_flmg_2#filmography">
#              <span class="ghost">
#               by
#              </span>
#              Job
#             </a>
#            </span>
#           </li>
#           <li class="subnav_item_main">
#            <span class="nobr-only">
#             <a class="link" href="/filmosearch?sort=user_rating&amp;explore=title_type&amp;role=nm0000199&amp;ref_=nm_ql_flmg_3">
#              <span class="ghost">
#               by
#              </span>
#              Ratings
#             </a>
#            </span>
#           </li>
#           <li class="subnav_item_main">
#            <span class="nobr-only">
#             <a class="link" href="/filmosearch?sort=num_votes&amp;explore=title_type&amp;role=nm0000199&amp;ref_=nm_ql_flmg_4">
#              <span class="ghost">
#               by
#              </span>
#              Votes
#             </a>
#            </span>
#           </li>
#           <li class="subnav_item_main">
#            <span class="nobr-only">
#             <a class="link" href="/filmosearch?sort=moviemeter&amp;explore=genres&amp;role=nm0000199&amp;ref_=nm_ql_flmg_5">
#              <span class="ghost">
#               by
#              </span>
#              Genre
#             </a>
#            </span>
#           </li>
#           <li class="subnav_item_main">
#            <span class="nobr-only">
#             <a class="link" href="/filmosearch?sort=moviemeter&amp;explore=keywords&amp;role=nm0000199&amp;ref_=nm_ql_flmg_6">
#              <span class="ghost">
#               by
#              </span>
#              Keyword
#             </a>
#            </span>
#           </li>
#          </ul>
#          <h4>
#           Personal Details
#          </h4>
#          <ul class="quicklinks">
#           <li class="subnav_item_main">
#            <span class="nobr-only">
#             <a class="link" href="/name/nm0000199/bio?ref_=nm_ql_pdtls_1">
#              Biography
#             </a>
#            </span>
#           </li>
#           <li class="subnav_item_main">
#            <span class="nobr-only">
#             <a class="link" href="/name/nm0000199/otherworks?ref_=nm_ql_pdtls_2">
#              Other Works
#             </a>
#            </span>
#           </li>
#           <li class="subnav_item_main">
#            <span class="nobr-only">
#             <a class="link" href="/name/nm0000199/publicity?ref_=nm_ql_pdtls_3">
#              Publicity Listings
#             </a>
#            </span>
#           </li>
#           <li class="subnav_item_main">
#            <span class="nobr-only">
#             <a class="link ghost" href="/name/nm0000199/officialsites?ref_=nm_ql_pdtls_4">
#              Official Sites
#             </a>
#            </span>
#           </li>
#           <li class="subnav_item_main">
#            <span class="nobr-only">
#             <a href="https://pro.imdb.com/name/nm0000199?rf=cons_nm_ql_contact&amp;ref_=cons_nm_ql_contact">
#              Contact Info
#              <span class="ghost quicklink_modifier">
#               (IMDbPro)
#              </span>
#             </a>
#            </span>
#           </li>
#          </ul>
#          <h4>
#           Did You Know?
#          </h4>
# ...
#           </path>
#           <path d="M18.003,16.231 C17.588,16.231 17.381,16.023 17.381,15.608 L17.381,1.088 C17.381,0.673 17.588,0.466 18.003,0.466 L19.37,0.466 C19.578,0.466 19.738,0.508 19.852,0.59 C19.966,0.673 20.044,0.829 20.086,1.057 L20.273,2.207 C22.241,0.735 24.315,0 26.491,0 C28.004,0 29.155,0.398 29.942,1.196 C30.73,1.995 31.124,3.151 31.124,4.664 L31.124,15.608 C31.124,16.023 30.917,16.231 30.503,16.231 L28.668,16.231 C28.253,16.231 28.046,16.023 28.046,15.608 L28.046,5.69 C28.046,4.592 27.823,3.782 27.377,3.265 C26.931,2.746 26.232,2.486 25.279,2.486 C23.641,2.486 22.034,3.016 20.459,4.073 L20.459,15.608 C20.459,16.023 20.251,16.231 19.837,16.231 L18.003,16.231" fill="#232F3E">
#           </path>
#           <path d="M148.483,16.572 C146.037,16.572 144.166,15.872 142.871,14.474 C141.575,13.074 140.927,11.048 140.927,8.395 C140.927,5.763 141.595,3.726 142.932,2.285 C144.27,0.845 146.161,0.124 148.607,0.124 C149.726,0.124 150.825,0.32 151.903,0.715 C152.131,0.798 152.292,0.901 152.385,1.025 C152.478,1.149 152.525,1.357 152.525,1.648 L152.525,2.486 C152.525,2.902 152.389,3.108 152.12,3.108 C152.016,3.108 151.851,3.078 151.624,3.016 C150.773,2.767 149.913,2.643 149.043,2.643 C147.302,2.643 146.047,3.083 145.28,3.964 C144.512,4.845 144.13,6.249 144.13,8.178 L144.13,8.581 C144.13,10.468 144.518,11.852 145.296,12.732 C146.073,13.613 147.302,14.054 148.98,14.054 C149.851,14.054 150.784,13.909 151.779,13.618 C152.007,13.557 152.162,13.525 152.245,13.525 C152.514,13.525 152.649,13.732 152.649,14.148 L152.649,14.986 C152.649,15.256 152.608,15.453 152.525,15.577 C152.442,15.701 152.276,15.815 152.027,15.92 C151.011,16.355 149.83,16.572 148.483,16.572" fill="#232F3E">
#           </path>
#           <path d="M162.319,16.696 C159.956,16.696 158.11,15.961 156.785,14.489 C155.458,13.018 154.795,10.966 154.795,8.332 C154.795,5.722 155.458,3.679 156.785,2.207 C158.11,0.735 159.956,0 162.319,0 C164.682,0 166.527,0.735 167.853,2.207 C169.18,3.679 169.844,5.722 169.844,8.332 C169.844,10.966 169.18,13.018 167.853,14.489 C166.527,15.961 164.682,16.696 162.319,16.696 M162.319,14.21 C165.242,14.21 166.703,12.25 166.703,8.332 C166.703,4.436 165.242,2.487 162.319,2.487 C159.396,2.487 157.935,4.436 157.935,8.332 C157.935,12.25 159.396,14.21 162.319,14.21" fill="#232F3E">
#           </path>
#           <path d="M174.259,16.231 C173.844,16.231 173.637,16.023 173.637,15.608 L173.637,1.088 C173.637,0.673 173.844,0.466 174.259,0.466 L175.627,0.466 C175.835,0.466 175.995,0.508 176.108,0.59 C176.222,0.673 176.301,0.829 176.342,1.057 L176.529,2.052 C178.519,0.684 180.457,0 182.344,0 C184.271,0 185.577,0.735 186.261,2.207 C188.313,0.735 190.365,0 192.417,0 C193.847,0 194.946,0.403 195.713,1.212 C196.48,2.021 196.864,3.171 196.864,4.664 L196.864,15.608 C196.864,16.023 196.657,16.231 196.242,16.231 L194.407,16.231 C193.992,16.231 193.785,16.023 193.785,15.608 L193.785,5.534 C193.785,4.498 193.588,3.731 193.195,3.232 C192.801,2.735 192.178,2.486 191.329,2.486 C189.815,2.486 188.292,2.953 186.759,3.886 C186.779,4.031 186.79,4.187 186.79,4.353 L186.79,15.608 C186.79,16.023 186.582,16.231 186.168,16.231 L184.333,16.231 C183.918,16.231 183.712,16.023 183.712,15.608 L183.712,5.534 C183.712,4.498 183.513,3.731 183.121,3.232 C182.726,2.735 182.104,2.486 181.255,2.486 C179.679,2.486 178.166,2.943 176.715,3.855 L176.715,15.608 C176.715,16.023 176.508,16.231 176.093,16.231 L174.259,16.231" fill="#232F3E">
#           </path>
#           <path d="M202.025,22.636 C201.61,22.636 201.403,22.428 201.403,22.014 L201.403,1.088 C201.403,0.673 201.61,0.466 202.025,0.466 L203.393,0.466 C203.807,0.466 204.047,0.673 204.108,1.088 L204.263,2.083 C205.84,0.694 207.591,0 209.519,0 C211.529,0 213.115,0.731 214.276,2.191 C215.436,3.652 216.017,5.638 216.017,8.146 C216.017,10.695 215.406,12.737 214.182,14.272 C212.96,15.805 211.332,16.572 209.302,16.572 C207.435,16.572 205.829,15.961 204.481,14.738 L204.481,22.014 C204.481,22.428 204.273,22.636 203.859,22.636 L202.025,22.636 Z M208.586,14.085 C211.446,14.085 212.877,12.157 212.877,8.302 C212.877,6.332 212.529,4.871 211.835,3.918 C211.14,2.964 210.078,2.486 208.648,2.486 C207.176,2.486 205.788,2.964 204.481,3.918 L204.481,12.592 C205.829,13.587 207.196,14.085 208.586,14.085 Z" fill="#232F3E">
#           </path>
#           <path d="M223.666,16.634 C222.194,16.634 221.017,16.215 220.136,15.376 C219.255,14.535 218.815,13.411 218.815,12.002 C218.815,10.488 219.354,9.281 220.432,8.379 C221.51,7.478 222.961,7.026 224.785,7.026 C225.946,7.026 227.252,7.202 228.703,7.556 L228.703,5.503 C228.703,4.384 228.448,3.597 227.941,3.14 C227.432,2.684 226.568,2.456 225.345,2.456 C223.915,2.456 222.515,2.664 221.147,3.078 C220.67,3.224 220.37,3.295 220.245,3.295 C219.997,3.295 219.872,3.109 219.872,2.736 L219.872,1.897 C219.872,1.627 219.914,1.43 219.997,1.305 C220.079,1.181 220.245,1.068 220.494,0.963 C221.136,0.674 221.95,0.44 222.934,0.264 C223.919,0.088 224.898,0 225.874,0 C227.843,0 229.294,0.409 230.226,1.228 C231.16,2.047 231.626,3.295 231.626,4.974 L231.626,15.608 C231.626,16.023 231.418,16.231 231.004,16.231 L229.667,16.231 C229.272,16.231 229.045,16.033 228.982,15.64 L228.827,14.613 C228.081,15.256 227.258,15.754 226.355,16.106 C225.453,16.458 224.556,16.634 223.666,16.634 M224.412,14.303 C225.095,14.303 225.811,14.168 226.557,13.898 C227.303,13.63 228.019,13.235 228.703,12.716 L228.703,9.546 C227.584,9.276 226.485,9.141 225.407,9.141 C223.064,9.141 221.893,10.042 221.893,11.847 C221.893,12.635 222.111,13.24 222.547,13.665 C222.982,14.09 223.603,14.303 224.412,14.303" fill="#232F3E">
#           </path>
#           <path d="M236.818,16.231 C236.404,16.231 236.197,16.023 236.197,15.608 L236.197,1.088 C236.197,0.673 236.404,0.466 236.818,0.466 L238.186,0.466 C238.393,0.466 238.554,0.508 238.668,0.59 C238.782,0.673 238.86,0.829 238.901,1.057 L239.089,2.207 C241.057,0.735 243.131,0 245.306,0 C246.82,0 247.97,0.398 248.758,1.196 C249.546,1.995 249.94,3.151 249.94,4.664 L249.94,15.608 C249.94,16.023 249.732,16.231 249.318,16.231 L247.483,16.231 C247.068,16.231 246.861,16.023 246.861,15.608 L246.861,5.69 C246.861,4.592 246.638,3.782 246.193,3.265 C245.747,2.746 245.048,2.486 244.094,2.486 C242.457,2.486 240.85,3.016 239.274,4.073 L239.274,15.608 C239.274,16.023 239.067,16.231 238.652,16.231 L236.818,16.231" fill="#232F3E">
#           </path>
#           <path d="M255.319,23.009 C254.655,23.009 254.064,22.937 253.547,22.791 C253.298,22.729 253.127,22.625 253.034,22.481 C252.94,22.335 252.893,22.128 252.893,21.858 L252.893,21.05 C252.893,20.656 253.049,20.458 253.36,20.458 C253.464,20.458 253.619,20.48 253.826,20.522 C254.033,20.563 254.313,20.584 254.666,20.584 C255.432,20.584 256.039,20.391 256.485,20.008 C256.93,19.624 257.329,18.945 257.682,17.972 L258.272,16.386 L252.271,1.585 C252.127,1.233 252.054,0.984 252.054,0.839 C252.054,0.591 252.199,0.466 252.49,0.466 L254.355,0.466 C254.686,0.466 254.915,0.518 255.039,0.622 C255.164,0.726 255.287,0.953 255.412,1.306 L259.765,13.37 L263.964,1.306 C264.088,0.953 264.212,0.726 264.336,0.622 C264.461,0.518 264.688,0.466 265.02,0.466 L266.76,0.466 C267.051,0.466 267.197,0.591 267.197,0.839 C267.197,0.984 267.124,1.233 266.979,1.585 L260.138,18.997 C259.579,20.428 258.926,21.453 258.179,22.075 C257.433,22.697 256.48,23.009 255.319,23.009" fill="#232F3E">
#           </path>
#          </g>
#         </svg>
#        </span>
#       </div>
#      </div>
#      <table class="footer" id="amazon-affiliates">
#       <tr>
#        <td colspan="8">
#         Amazon Affiliates
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <div>
#          <a class="amazon-affiliate-site-link" href="/offsite/?page-action=ft-aiv&amp;token=BCYtoH7vBMD6c6wQO46QbQE9685scuC42qHUAlChQKggKqp4qwJnv3d6XM-Cq7aB2U2zgmDpMDjh%0D%0AvPqxqqlC7iu3p3-3b_6EtjbTVYmxfNwssLG43g0mIXwOMniJXKWJ1D73gF08R0KbXo_PjMUlm4q-%0D%0ANFn72LdHQvuuREanVlnUf-rmmh7VAFpdaDGrJlYpkH3Us7XnYjmLnw6FDsMdFxfUB3IFzoSqrQQY%0D%0AUk7sqDs7XYM%0D%0A">
#           <span class="amazon-affiliate-site-name">
#            Amazon Video
#           </span>
#           <br/>
#           <span class="amazon-affiliate-site-desc">
#            Watch Movies &amp;
#            <br/>
#            TV Online
#           </span>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div>
#          <a class="amazon-affiliate-site-link" href="/offsite/?page-action=ft-piv&amp;token=BCYiRaE23PbRdjLCPpYfAJVHuXthia78_HzJUAka-P7rSI12T4Hk9qtc4vrMOMAUgJw_V8PvsVNU%0D%0A5Tyj_5OpjjAcMsNWa--PBSrQEL6fmHOfWqonGACZ-U39qI0Qa_w2_p3n5D3OoAIPNF_8D-8RRmLN%0D%0AABkCMv23e0wv27SGqzlAPwEK_TbkmNHjXs8_LvFwiu_15Hn03d82sALtT1PGF8h1bZIvZWt_9q0q%0D%0AcwD7E7ForPs%0D%0A">
#           <span class="amazon-affiliate-site-name">
#            Prime Video
#           </span>
#           <br/>
#           <span class="amazon-affiliate-site-desc">
#            Unlimited Streaming
#            <br/>
#            of Movies &amp; TV
#           </span>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div>
#          <a class="amazon-affiliate-site-link" href="/offsite/?page-action=ft-amzn-de&amp;token=BC